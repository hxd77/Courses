# %%
import os
from dotenv import load_dotenv

load_dotenv()  # 加载环境变量
API_KEY = os.getenv("API_KEY")
BASE_URL = os.getenv("BASE_URL")
if not API_KEY:
    raise ValueError("未检测到 API_KEY，请检查 .env 文件是否配置正确")

# %%
#(1)调用OpenAI的ChatModel
from langchain_openai import ChatOpenAI

#1.初始化对话模型
chat_model=ChatOpenAI(
    model="mimo-v2.5-pro", #选择对话模型
    api_key=API_KEY,
    base_url=BASE_URL,
    temperature=0.3,  # 随机性：0-1，越小越严谨，越大越有创造力
    max_tokens=800  # 最大生成 tokens 数，避免生成过长内容
)
# Out:
# c:\Users\DELL\AppData\Local\Programs\Python\Python310\lib\site-packages\requests\__init__.py:109: RequestsDependencyWarning: urllib3 (2.7.0) or chardet (7.4.3)/charset_normalizer (3.4.7) doesn't match a supported version!
#   warnings.warn(

# %%
#2. 构造对话模型
#ChatModel需要接收的是"消息列表",每个消息有角色(user/assistant/system)和内容
messages=[
    #system消息:给助手设定身份和行为准则，会影响后续所有回复
    {'role':"system","content":"你是一个耐心的AI学习助手,回复简洁易懂,适合高校学生理解。"},
    #user消息: 用户的问题
    {"role":"user","content":"请用3句话解释什么是LangChain?"}
]

# %%
#3. 调用模型生成结果
#统一调用方法: invoke(),传入消息列表
result=chat_model.invoke(messages)

# %%
#4.输出结果
#结果是一个ChatMessage对象,content属性是回复内容
print("ChatModel回复: ")
print(result.content)
# Out:
# ChatModel回复:
# 1. **LangChain是一个开源框架**，专门为大语言模型（如ChatGPT）设计的“工具箱”，让开发者能更轻松地构建基于AI的应用。
#
# 2. **它像“乐高积木”**，将模型、数据、外部工具等模块封装成可组合的组件，简化开发流程，避免重复造轮子。
#
# 3. **核心作用是“连接”**，帮助语言模型调用外部工具（如搜索引擎、数据库）、记忆历史对话，实现更复杂、实际的任务。

# %%
# 初始化对话历史（包含 system 设定）
history = [
    {"role": "system", "content": "你是一个耐心的AI学习助手，回复简洁易懂，适合高校学生理解。"}
]

# 第一轮对话
history.append({"role": "user", "content": "请用3句话解释什么是LangChain？"})

result = chat_model.invoke(history)
print("【第一轮回复】：")
print(result.content)

# 将模型的回复添加到历史中（assistant 消息）
history.append({"role": "assistant", "content": result.content})

# 第二轮对话
# 追问，模型需要上下文才能理解"它"
history.append({"role": "user", "content": "它的核心组件有哪些？"})

result = chat_model.invoke(history)
print("\n【第二轮回复】：")
print(result.content)

# 继续记录
history.append({"role": "assistant", "content": result.content})

# 第三轮对话
history.append({"role": "user", "content": "给我一个简单的使用场景"})

result = chat_model.invoke(history)
print("\n【第三轮回复】：")
print(result.content)
# Out:
# 【第一轮回复】：
# LangChain是一个用于构建基于大语言模型（LLM）应用程序的开发框架。它通过模块化的方式将LLM与外部数据源、计算工具连接起来。其核心是通过“链式调用”实现复杂的交互流程和任务自动化。
#
# 【第二轮回复】：
# LangChain 的核心组件可以看作搭建智能应用的“工具箱”，主要包括以下几个关键部分：
#
# 1.  **模型（Models）**：这是应用的“大脑”，负责调用各类大语言模型或嵌入模型来生成或理解文本。
# 2.  **提示模板（Prompt Templates）**：这是给模型的“指令模板”，用于构建标准化、可复用的用户输入，从而引导模型产生期望的输出。
# 3.  **索引（Indexes）**：这是应用的“外部记忆库”，用于存储和检索外部数据（如文档、数据库），让模型能够基于特定信息进行回答。
# 4.  **链（Chains）**：这是“工作流编排器”，将模型、提示、工具等多个组件串联起来，按顺序执行，以完成一个复杂的多步骤任务。
# 5.  **记忆（Memory）**：这是对话的“短期记忆”，用于在多轮交互中保存和传递上下文信息，让对话具有连贯性。
# 6.  **代理（Agents）**：这是“智能决策者”，赋予模型自主选择并使用工具（如搜索引擎、计算器）的能力，使其能够动态地规划完成任务。
#
# **核心协作流程**：一个典型的智能应用会先通过**提示模板**构建问题，由**模型**思考，必要时借助**索引**查询知识、使用**代理**调用**工具**，并利用**记忆**维持对话，整个过程由**链**进行编排，从而构建出强大的自动化应用。例如，一个公司内部助手可以：接收问题（提示） -> 查询内部文档库（索引） -> 分析生成答案（模型） -> 保持多轮对话（记忆）。
#
# 【第三轮回复】：
# 一个简单场景是**个人知识库问答助手**。
#
# 你可以用LangChain快速搭建一个程序：
# 1. 将你的课程笔记、教材等文档（作为外部数据）导入，并通过**索引**组件拆分、存储为向量。
# 2. 当你提问“这次考试的重点是什么？”时，**链**会先从知识库中检索相关段落，再将段落和问题一起交给大模型。
# 3. 模型基于检索到的内容生成答案，就像一个理解你所有资料的私人助教。
#
# 整个过程自动化，无需手动翻找资料。

# %%
# 先安装Hugging Face相关依赖（终端执行）
# pip install langchain-huggingface transformers torch

# 导入Hugging Face的LLM接口
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

# 1. 加载Hugging Face的模型和tokenizer
model_name = "./models/Qwen/Qwen3-0___6B"  # 模型名 这是本地路径 这里替换成自己的路径！！
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name)

# 2. 构建pipeline
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    max_new_tokens=200,
    temperature=0.3
)

# 3. 初始化LangChain的LLM接口（统一接口）
hf_llm = HuggingFacePipeline(pipeline=pipe)

# 4. 调用模型（和之前的LLM调用方式完全一样）
prompt = "请用3句话解释什么是LangChain？"
result = hf_llm.invoke(prompt)

print("Hugging Face模型回复：")
print(result)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 5
#       1 # 先安装Hugging Face相关依赖（终端执行）
#       2 # pip install langchain-huggingface transformers torch
#       3
#       4 # 导入Hugging Face的LLM接口
# ----> 5 from langchain_huggingface import HuggingFacePipeline
#       6 from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
#       8 # 1. 加载Hugging Face的模型和tokenizer
#
# ModuleNotFoundError: No module named 'langchain_huggingface'

# %% [markdown]
# ## 2.2 提示词模板(PromptTemplate): 让提示更规范、可复用

# %% [markdown]
# ### 2.2.1 提示词模板基础用法: 标准化提示与动态参数

# %%
#2.2提示词模板
from langchain_core.prompts import PromptTemplate

#1.定义提示词模板
#input_variables: 动态参数列表(这里是user_role和subject)
#template: 提示词模板字符串,用{参数名}表示动态参数
prompt_template=PromptTemplate(
    input_variables=["user_role","subject"],
    template="请给{user_role}写一段50字左右的{subject}学习建议,语言简洁实用,分2个小要点"
)

#2.格式化模板(传入具体参数,生成完整提示词)
# 给"高校学生"生成"LangChain"学习建议
formatted_promt=prompt_template.format(
    user_role="高校学生",
    subject="LangChain"
)
print("格式化后的提示词: ")
print(formatted_promt)
# Out:
# 格式化后的提示词:
# 请给高校学生写一段50字左右的LangChain学习建议,语言简洁实用,分2个小要点

# %%
#3.调用模型生成结果
result=chat_model.invoke([{"role":"user","content":formatted_promt}])

print("\n生成的学习建议: ")
print(result.content)
# Out:
# 生成的学习建议:
# **LangChain学习建议**
#
# 1. **先跑通再理解**：从官方Quickstart示例入手，动手搭建一个简单的对话链，边跑边看文档，建立直观感受。
#
# 2. **以项目驱动**：选一个小场景（如文档问答、知识库检索），拆解Chain→Agent→Memory的调用流程，在实践中掌握核心模块。

# %%
#如果想给"程序员"生成"AI Agent"的学习建议,只需要修改format()中的参数
formatted_prompt=prompt_template.format(
    user_role="程序员",
    subject="AI Agent"
)
result=chat_model.invoke([{"role":"user","content":formatted_prompt}])
print("给程序员的AI Agent学习建议: ")
print(result.content)
# Out:
# 给程序员的AI Agent学习建议:
# ## AI Agent 学习建议
#
# 1. **掌握工具调用**：熟悉 Function Calling、API 编排，让 Agent 具备"手脚"。
# 2. **学好 Prompt 工程**：理解任务分解与状态管理，这是 Agent 的"大脑"。

# %% [markdown]
# ### 2.2.2 提示词模板进阶用法:少样本提示模板

# %%
"""
有时候，简单的提示词模板不足以让模型理解我们的需求——比如我们希望模型生成“特定格式”的内容（比如分点、带编号、有固定结构）。这时候就需要“少样本提示”：给模型看几个示例，让它照着示例的格式生成内容。
LangChain的FewShotPromptTemplate就是专门做这个的。
"""
#1.定义示例(少样本的核心:给模型看的参考案例)
examples=[
    {
        "subject":"Python编程",
        "method":"核心目标: 掌握基础语法和常用库；学习步骤：1. 学习变量、函数等基础语法 2. 实操小项目（如计算器） 3. 学习Pandas、Matplotlib库；注意事项：多动手实操，遇到错误及时调试。"
    },
    {
        "subject":"机器学习",
        "method":"核心目标：理解基础算法原理和应用场景；学习步骤：1. 复习数学基础（线性代数、概率） 2. 学习经典算法（线性回归、决策树） 3. 用Scikit-learn实操；注意事项：先理解原理，再动手实现，避免死记硬背。"
    }
]

# %%
example_template="""
学科:{subject}
学习方法: {method}
"""

# %%
from langchain_core.prompts import FewShotPromptTemplate, PromptTemplate

# 3. 定义最终的提示词模板（包含示例和用户需求）
few_shot_prompt = FewShotPromptTemplate(
    examples=examples,                # 传入示例
    example_prompt=PromptTemplate(
        input_variables=["subject", "method"],
        template=example_template
    ),
    example_separator="\n",
    prefix="少样本提示词：",
    suffix="参考以上样本，回答：\n学科：{new_subject}\n学习方法：",  # 最终给用户的提示（在示例之后）
    input_variables=["new_subject"]   # 动态参数：用户要查询的新学科
)

# %%
# 4. 格式化模板（传入新学科：LangChain
formatted_prompt = few_shot_prompt.format(new_subject="LangChain")
print(formatted_prompt)
# Out:
# 少样本提示词：
#
# 学科:Python编程
# 学习方法: 核心目标: 掌握基础语法和常用库；学习步骤：1. 学习变量、函数等基础语法 2. 实操小项目（如计算器） 3. 学习Pandas、Matplotlib库；注意事项：多动手实操，遇到错误及时调试。
#
#
# 学科:机器学习
# 学习方法: 核心目标：理解基础算法原理和应用场景；学习步骤：1. 复习数学基础（线性代数、概率） 2. 学习经典算法（线性回归、决策树） 3. 用Scikit-learn实操；注意事项：先理解原理，再动手实现，避免死记硬背。
#
# 参考以上样本，回答：
# 学科：LangChain
# 学习方法：

# %%
# 5. 调用模型生成结果
result = chat_model.invoke([{"role": "user", "content": formatted_prompt}])

print("生成的LangChain学习方法 (AI回复)：")
print(result.content)
# Out:
# 生成的LangChain学习方法 (AI回复)：
# 学科：LangChain
# 学习方法：
# 核心目标：掌握LangChain框架的核心概念与组件，能够独立构建基于大语言模型的应用程序。
# 学习步骤：
# 1. 学习基础概念（链（Chain）、代理（Agent）、记忆（Memory）、索引（Index）等核心模块），了解其设计思想与典型使用场景。
# 2. 动手实操基础应用，例如：使用LLMChain实现问答、使用Document Loader加载文档、使用VectorStore进行检索。
# 3. 完成一个综合小项目（如构建一个简单的知识库问答机器人或自动化文档处理流水线），整合多个组件。
# 注意事项：
# - LangChain版本迭代快，注意结合官方文档和最新示例学习。
# - 务必结合实际场景多编码实践，理解组件间的数据流动。
# - 遇到问题时，善用社区资源（如GitHub Issues、论坛），并学会阅读源码调试。

# %% [markdown]
# ### 2.2.3工程化实践: 少样本提示模板的高效管理

# %%
"""
工程化场景中使用少样本模板的常见问题及对应方案：

- 示例过多导致提示词冗长：使用ExampleSelector动态筛选相关示例，避免冗余
- 示例维护困难：将示例存储在文件（JSON/CSV）中，批量加载与更新
- 不同场景需要不同示例：按输入参数匹配示例类型，实现场景化示例分发
"""
import json

#2. 工程化示例管理: 从JSON文件中加载示例
with open("learning_method_examples.json","r",encoding="utf-8") as f:
    example=json.load(f) #从JSON中直接提取示例数据列表

# %%
from langchain_core.example_selectors import BaseExampleSelector,LengthBasedExampleSelector
from langchain_core.prompts import PromptTemplate
from typing import Dict,List

#3.Example:按长度筛选示例(控制提示词总长度)
# example_selector = LengthBasedExampleSelector(
#     examples=examples,
#     example_prompt=PromptTemplate(
#         input_variables=["subject", "difficulty", "method"],
#         template="学科：{subject}\n难度：{difficulty}\n学习方法：{method}\n"
#     ),
#     max_length=150,  # 控制示例总长度，避免提示词过长
#     get_text_length=lambda x: len(x)  # 长度计算函数
# )

#4.自定义ExampleSelector:按难度筛选示例(输入含difficulty参数)
class DifficultyExampleSelector(BaseExampleSelector):
    """根据用户输入的difficulty字段筛选样本"""
    def __init__(self,examples:List[Dict[str,str]]):
        self.examples=examples
    
    def add_example(self,example:Dict[str,str])->None:
        self.examples.append(example)
    
    def select_examples(self, input_variables:Dict[str,str])->List[Dict]:
        #获取用户输入的难度等级,如果没有提供则默认为'easy'
        target_difficulty=input_variables.get('difficulty','easy')

        #过滤出匹配难度的所有示例
        return [ex for ex in self.examples if ex.get("difficulty")==target_difficulty]
    
example_selector=DifficultyExampleSelector(examples=example)

# %%
from langchain_core.prompts import FewShotPromptTemplate, PromptTemplate

# 4. 构建工程化少样本模板
few_shot_prompt = FewShotPromptTemplate(
    example_selector=example_selector,  # 替换固定examples为动态选择器
    example_prompt=PromptTemplate(
        input_variables=["subject", "difficulty", "method"],
        template="学科：{subject}\n难度：{difficulty}\n学习方法：{method}\n"
    ),
    example_separator="\n",
    prefix="少样本提示：",
    suffix="参考以上示例，回答：\n学科：{new_subject}\n难度：{difficulty}\n学习方法：",
    input_variables=["new_subject", "difficulty"]  # 新增难度参数
)

# %%
#5.动态生成不同难度的提示词
#场景1: 生成入门级LangChain学习方法
formatted_prompt_easy=few_shot_prompt.format(
    new_subject="LangChain",
    difficulty="easy"
)
print(formatted_prompt_easy)
result_easy=chat_model.invoke([{"role":"user","content":formatted_prompt_easy}])
print("\n入门级学习方法(AI回复)")
print(result_easy.content)
# Out:
# 少样本提示：
# 学科：Python编程（入门）
# 难度：easy
# 学习方法：核心目标：掌握基础语法；学习步骤：1.变量与数据类型 2.条件语句；注意事项：边学边练
#
# 学科：机器学习（入门）
# 难度：easy
# 学习方法：核心目标：理解基础概念；学习步骤：1.数据预处理 2.简单模型；注意事项：用Excel辅助理解
#
# 参考以上示例，回答：
# 学科：LangChain
# 难度：easy
# 学习方法：
#
# 入门级学习方法(AI回复)
# **学科：LangChain**
# **难度：easy**
# **学习方法：**
# - **核心目标**：理解LangChain的核心组件，能搭建简单的LLM应用。
# - **学习步骤**：
#   1. **环境搭建与基础概念**：安装LangChain并理解其核心模块（如Models、Prompts、Indexes、Chains）。
#   2. **组件实践**：通过调用大语言模型（如OpenAI）、设计提示模板，体验基础功能。
#   3. **链式应用**：学习使用Chain串联多个步骤，实现简单问答或任务流程。
#   4. **实战小项目**：尝试结合外部数据（如网页、文档）构建一个基础问答机器人。
# - **注意事项**：
#   - 边学边动手，多运行示例代码并尝试修改参数。
#   - 遇到问题时，优先查阅官方文档和社区案例。
#   - 从简单场景开始，避免一开始就探索复杂功能。

# %%
#场景2:生成进阶级LangChain学习方法
formatted_prompt_hard=few_shot_prompt.format(
    new_subject="LangChain",
    difficulty="hard"
)

print(formatted_prompt_hard)
result_hard=chat_model.invoke([{"role":"user","content":formatted_prompt_hard}])
print("\n进阶级学习方法(AI回复)")
print(result_hard.content)
# Out:
# 少样本提示：
# 学科：Python编程（进阶）
# 难度：hard
# 学习方法：核心目标：掌握面向对象与库开发；学习步骤：1.类与对象 2.模块开发；注意事项：参与开源项目
#
# 学科：机器学习（进阶）
# 难度：hard
# 学习方法：核心目标：掌握模型优化；学习步骤：1.特征工程 2.超参数调优；注意事项：研读论文复现实验
#
# 参考以上示例，回答：
# 学科：LangChain
# 难度：hard
# 学习方法：
#
# 进阶级学习方法(AI回复)
# **学科：LangChain**
# **难度：hard**
# **学习方法：**
# - **核心目标**：掌握基于大语言模型的复杂应用架构设计与开发能力，熟练运用LangChain的链（Chain）、代理（Agent）、工具（Tool）等模块构建自动化AI系统。
# - **学习步骤**：
#   1. **核心模块深入**：理解LangChain的核心架构（模型、提示模板、链、代理、记忆模块），重点掌握“链”的组合逻辑与“代理”的动态决策机制。
#   2. **实战项目开发**：基于LangChain构建完整应用（如：智能客服、自动化数据分析工具、知识库问答系统），实践与外部工具/API的集成及多模态任务处理。
# - **注意事项**：
#   1. **社区与生态跟踪**：积极参与LangChain开源社区，关注其迭代动态及配套工具（如LangSmith、LangGraph），及时适配新技术范式。
#   2. **底层原理理解**：深入研究大语言模型的推理机制与提示工程原理，避免过度依赖框架封装，培养底层调试与优化能力。

# %% [markdown]
# ## 2.3 输出解析: 让输出更可控
# #### 2.3.2.2 案例1: StrOutputParser

# %%
#2.3输出解析: 让输出更可控

from langchain_core.output_parsers import StrOutputParser

#1.创建StrOutputparser
#核心作用:将LLM返回的AIMessage对象,统一转为纯字符串(str)
parser=StrOutputParser()

# %%
#2. 链式调用: 模型->字符串解析
chain=chat_model|parser 
result=chain.invoke("请简要介绍 LangChain 输出解析层的作用")

print("StrOutputParser 解析后的字符串: ")
print(result)
print("\n解析结果类型: ",type(result)) #str
# Out:
# StrOutputParser 解析后的字符串:
# LangChain 的**输出解析层（Output Parsers）** 是负责将语言模型的原始文本输出转换为结构化、可用数据的关键组件。其主要作用包括：
#
# 1. **结构化输出**：将模型的非结构化响应（如自由文本）转换为标准格式（如 JSON、列表、枚举等），便于程序处理。
# 2. **数据验证与格式化**：确保输出符合预定义的模式（例如，通过 Pydantic 模型校验字段），避免格式错误。
# 3. **引导提示优化**：部分解析器（如 `PydanticOutputParser`）会自动生成格式要求，并嵌入到提示中，引导模型按指定结构输出。
# 4. **错误处理与重试**：在输出不符合预期时，可触发重试或提供修正反馈（例如 `RetryWithErrorOutputParser`）。
# 5. **无缝集成链流程**：作为链（Chain）的一部分，实现从输入到结构化输出的端到端自动化。
#
# **常见解析器示例**：
# - `PydanticOutputParser`：通过 Pydantic 模型定义输出结构。
# - `CommaSeparatedListOutputParser`：解析逗号分隔的列表。
# - `BooleanOutputParser`：输出布尔值。
#
# **简单工作流**：
# ```
# 用户查询 → 提示模板（含解析器格式指导） → 模型响应 → 解析器转换 → 结构化数据
# ```
# 通过输出解析层，LangChain 能够更可靠地将语言模型集成到需要严格数据格式的应用程序中（如 API 交互、数据分析等）。
#
# 解析结果类型:  <class 'langchain_core.messages.base.TextAccessor'>

# %% [markdown]
# #### 2.3.2.2 案例2: JsonOutputParser

# %%
from langchain_core.output_parsers import JsonOutputParser

#1.创建JSON解析器
parser=JsonOutputParser()

# %%
from langchain_core.prompts import PromptTemplate

# 2. 构建提示模板（无需手动嵌入格式指令，解析器自动关联）
prompt = PromptTemplate(
    template="请介绍1个LangChain开发工具，输出工具名和核心功能。{format_instructions}",
    input_variables=[],
    partial_variables={"format_instructions": parser.get_format_instructions()}
)

# %%
# 3. 链式调用（LangChain ≥1.0.0 推荐方式，自动完成提示+调用+解析）
chain = prompt | chat_model | parser
result = chain.invoke({})  # 无输入参数，传入空字典

print("解析后的JSON（Python字典）：")
print(result)
print("获取单个字段：", result["tool_name"])  # 可直接用于业务逻辑
# Out:
# 解析后的JSON（Python字典）：
# {'tool_name': 'LangChain Agents', 'core_functionality': '允许构建智能代理，使用大语言模型动态选择和使用工具（如搜索引擎、计算器）来完成复杂任务，实现自动化决策和执行。'}
# 获取单个字段： LangChain Agents

# %% [markdown]
# #### 2.3.2.3 案例3: PydanticOutputParser

# %%
from pydantic import BaseModel, Field

# 1. 定义 Pydantic 数据模型
class ToolInfo(BaseModel):
    tool_name: str = Field(description="开发工具的名称，如 LangSmith")
    function: str = Field(description="工具的核心功能，30字以内")
    difficulty: str = Field(description="学习难度，仅可选：简单 / 中等 / 复杂")

# %%
from langchain_core.output_parsers import PydanticOutputParser

# 2. 创建解析器
parser = PydanticOutputParser(pydantic_object=ToolInfo)

# %%
# 3. Prompt + Chain
prompt = PromptTemplate(
    template="{user_input}，严格按照要求输出。\n{format_instructions}",
    input_variables=["user_input"],
    partial_variables={
        "format_instructions": parser.get_format_instructions()
    }
)

chain = prompt | chat_model | parser
result = chain.invoke({"user_input": "请介绍1个 Python 开发工具"})

# %%
print("解析后的结构化数据（Pydantic 模型对象）:")
print(result)
print("字段校验 difficulty：", result.difficulty)
print("转化为字典：", result.model_dump())
# Out:
# 解析后的结构化数据（Pydantic 模型对象）:
# tool_name='PyCharm' function='提供 Python 集成开发环境，支持代码编辑、调试和测试。' difficulty='中等'
# 字段校验 difficulty： 中等
# 转化为字典： {'tool_name': 'PyCharm', 'function': '提供 Python 集成开发环境，支持代码编辑、调试和测试。', 'difficulty': '中等'}

# %% [markdown]
# ### 2.3.3 BaseOutputParser

# %%
from langchain_core.output_parsers import BaseOutputParser

# 自定义解析器
class CustomToolParser(BaseOutputParser):
    def parse(self, text: str) -> dict:
        """将模型输出按 '工具名@核心功能@学习难度' 解析为字典"""
        text = text.strip().replace("\n", "").replace(" ", "")
        parts = text.split("@")
        if len(parts) != 3:
            raise ValueError(f"输出格式错误！需满足「工具名@核心功能@学习难度」，当前输出：{text}")
        return {
            "tool_name": parts[0].strip(),
            "function": parts[1].strip(),
            "difficulty": parts[2].strip()
        }

    def get_format_instructions(self) -> str:
        """生成提示词，引导模型按自定义格式输出"""
        return "请严格按照「工具名@核心功能@学习难度」格式输出，不添加多余内容。示例：LangSmith@全链路调试监控@中等"

# %%
# 使用解析器
parser = CustomToolParser()
prompt = PromptTemplate(
    template="请介绍1个LangChain开发工具。{format_instructions}",
    input_variables=[],
    partial_variables={"format_instructions": parser.get_format_instructions()}
)
chain = prompt | chat_model | parser
result = chain.invoke({})

print("自定义解析器解析结果：")
print(result)
print("解析结果类型：", type(result))
# Out:
# 自定义解析器解析结果：
# {'tool_name': 'LangServe', 'function': '部署LangChain应用为RESTAPI', 'difficulty': '中等'}
# 解析结果类型： <class 'dict'>
